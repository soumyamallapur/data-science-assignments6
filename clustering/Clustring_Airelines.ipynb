# %% [markdown]
# #### Perform clustering (hierarchical,K means clustering and DBSCAN) for the airlines data to obtain optimum number of clusters. Draw the inferences from the clusters obtained.

# %%
# importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
import scipy.cluster.hierarchy as sch
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score as sil, calinski_harabasz_score as chs, silhouette_samples
import warnings
warnings.filterwarnings('ignore')

# %%
#pip install yellowbrick

# %%
airline = pd.read_excel('C:/Users/soumy/documents/clustering/EastWestAirlines.xlsx',sheet_name='data')
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ###### rename column id# and award? to id and award

# %%
# Column rename.
airline.rename(columns={'ID#':'ID', 'Award?':'Award'}, inplace=True)

#Set ID as Index Column
airline.set_index('ID',inplace=True)
airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# ...

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3999 entries, 1 to 4021
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award              3999 non-null   int64
# dtypes: int64(11)
# memory usage: 374.9 KB

# %%
airline.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
def norm_fun(i):
    x = (i-i.min())/(i.max()-i.min())
    return x

# %%
airline_norm = norm_fun(airline.iloc[:,1:])
airline_norm.head()
# Out:
#     Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# ID
# 1          0.0       0.00        0.0        0.0     0.000660     0.011628
# 2          0.0       0.00        0.0        0.0     0.000815     0.023256
# 3          0.0       0.00        0.0        0.0     0.015636     0.046512
# 4          0.0       0.00        0.0        0.0     0.001896     0.011628
# 5          0.0       0.75        0.0        0.0     0.164211     0.302326
#
#     Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# ID
# 1            0.000000         0.000000           0.843742    0.0
# 2            0.000000         0.000000           0.839884    0.0
# 3            0.000000         0.000000           0.847842    0.0
# 4            0.000000         0.000000           0.837955    0.0
# 5            0.067398         0.075472           0.835905    1.0

# %% [markdown]
# ## Hierarchy clusters

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

dendrogram=sch.dendrogram(sch.linkage(airline_norm,method='ward'))

# %%
hc = AgglomerativeClustering(n_clusters=4,affinity='euclidean',linkage='complete')
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=4)

# %%
y_hc = hc.fit_predict(airline_norm)

# %%
airline['h_clusterid'] = hc.labels_
airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# ...

# %% [markdown]
# ## Kmeans

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(airline_norm)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('Elbow curv')
plt.xlabel('number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
model = KMeans(n_clusters=4)
model.fit(airline_norm)
model.labels_
# Out:
# array([1, 1, 1, ..., 2, 1, 1])

# %%
x = pd.Series(model.labels_)
airline['Clust'] = x

# %%
airline.iloc[:,1:5].groupby(airline.Clust).mean()
# Out:
#        Qual_miles  cc1_miles  cc2_miles  cc3_miles
# Clust
# 0.0    107.478261   2.136432   1.014993   1.005997
# 1.0    172.832186   1.946003   1.017470   1.013235
# 2.0    138.548507   2.257463   1.008706   1.016169
# 3.0    108.365260   2.086039   1.012987   1.011364

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
stscaler = StandardScaler().fit(airline.values)
x = stscaler.transform(airline.values)

# %%
# Assuming 'x' is your data in a Pandas DataFrame
x = airline.dropna()  # This will remove rows with NaN values

# %%
#x = airline.select_dtypes(include=['number'])

# %%
from sklearn.impute import SimpleImputer

# Initialize the imputer with the strategy you prefer (e.g., 'mean', 'median', 'most_frequent')
imputer = SimpleImputer(strategy='mean')

# Fit and transform the data to replace NaN values
X_imputed = imputer.fit_transform(airline)

# %%
dbscan = DBSCAN(eps=2,min_samples=5)
dbscan.fit(x)
# Out:
# DBSCAN(eps=2)

# %%
dbscan.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
cluster = pd.DataFrame(dbscan.labels_,columns=['cluster'])
cluster
# Out:
#       cluster
# 0          -1
# 1          -1
# 2          -1
# 3          -1
# 4          -1
# ...       ...
# 3971       -1
# 3972       -1
# 3973       -1
# 3974       -1
# 3975       -1
#
# [3976 rows x 1 columns]
