# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # question 1

# %%
name_of_company = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']
Measure_x = [24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00]

# %%
plt.boxplot(Measure_x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x245bf2f7880>,
#   <matplotlib.lines.Line2D at 0x245bf2f6020>],
#  'caps': [<matplotlib.lines.Line2D at 0x245bf2f7cd0>,
#   <matplotlib.lines.Line2D at 0x245bf2f6d40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x245bf283160>],
#  'medians': [<matplotlib.lines.Line2D at 0x245bf2f78e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x245bf2f5930>],
#  'means': []}

# %%
print('mean -->' , stat.mean(Measure_x))
print('variance -->' , stat.variance(Measure_x))
print('std_deviation -->' , stat.stdev(Measure_x))
# Out:
# mean --> 33.27133333333333
# variance --> 287.1466123809524
# std_deviation --> 16.945400921222028

# %%
# barplot
color_palette = "Set1"
sns.barplot(x=name_of_company,y=Measure_x,palette=color_palette)
plt.xticks(rotation=90)
plt.show()

# %%
Measure_x = pd.Series(Measure_x)
q1 = np.quantile(Measure_x,0.25)
q3 = np.quantile(Measure_x,0.75)
q2 = np.median(Measure_x)
IQR = q3 - q1
upper_bond = q3+(1.5*IQR)
lower_bond = q1-(1.5*IQR)
outliers = Measure_x[(Measure_x <= lower_bond) | (Measure_x >= upper_bond)]
print('The Outlier in the boxplot:',outliers)
# Out:
# The Outlier in the boxplot: 10    91.36
# dtype: float64
